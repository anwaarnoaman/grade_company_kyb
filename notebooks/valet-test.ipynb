# %%
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient

key_vault_url = "https://assessment-test.vault.azure.net/"
credential = DefaultAzureCredential()
client = SecretClient(vault_url=key_vault_url, credential=credential)

secret_key = client.get_secret("SECRET_KEY").value
 

print(secret_key)
# Out:
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: ERROR: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/de176ae2-4ec7-4ee3-bd31-41b09beaa447/' does not exist in tenant 'Default Directory' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: e6a5641e-b5d2-4880-be4c-3176c9810700 Correlation ID: 8e819979-1efe-498b-b424-c28c53d49fdd Timestamp: 2026-02-24 08:55:47Z
# Run the command below to authenticate interactively; additional arguments may be added as needed:
# az logout
# az login --tenant "14ea9a3f-f542-4917-9078-537d7ea3eb33" --scope "https://vault.azure.net/.default"
#
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 credential = DefaultAzureCredential()
#       6 client = SecretClient(vault_url=key_vault_url, credential=credential)
# ----> 8 secret_key = client.get_secret("SECRET_KEY").value
#      11 print(secret_key)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/keyvault/secrets/_client.py:65, in SecretClient.get_secret(self, name, version, **kwargs)
#      44 @distributed_trace
#      45 def get_secret(self, name: str, version: Optional[str] = None, **kwargs: Any) -> KeyVaultSecret:
#      46     """Get a secret. Requires the secrets/get permission.
#      47
#      48     :param str name: The name of the secret
#    (...)     63             :dedent: 8
#      64     """
# ---> 65     bundle = self._client.get_secret(
#      66         secret_name=name,
#      67         secret_version=version or "",
#      68         **kwargs
#      69     )
#      70     return KeyVaultSecret._from_secret_bundle(bundle)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/keyvault/secrets/_generated/_operations/_operations.py:802, in KeyVaultClientOperationsMixin.get_secret(self, secret_name, secret_version, **kwargs)
#     799 _request.url = self._client.format_url(_request.url, **path_format_arguments)
#     801 _stream = kwargs.pop("stream", False)
# --> 802 pipeline_response: PipelineResponse = self._client._pipeline.run(  # pylint: disable=protected-access
#     803     _request, stream=_stream, **kwargs
#     804 )
#     806 response = pipeline_response.http_response
#     808 if response.status_code not in [200]:
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_retry.py:545, in RetryPolicy.send(self, request)
#     543 self._configure_timeout(request, absolute_timeout, is_response_error)
#     544 request.context["retry_count"] = len(retry_settings["history"])
# --> 545 response = self.next.send(request)
#     546 if self.is_retry(retry_settings, response):
#     547     retry_active = self.increment(retry_settings, response=response)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/keyvault/secrets/_shared/challenge_auth_policy.py:111, in ChallengeAuthPolicy.send(self, request)
#      98 def send(self, request: PipelineRequest[HttpRequest]) -> PipelineResponse[HttpRequest, HttpResponse]:
#      99     """Authorize request with a bearer token and send it to the next policy.
#     100
#     101     We implement this method to account for the valid scenario where a Key Vault authentication challenge is
#    (...)    109     :rtype: ~azure.core.pipeline.PipelineResponse
#     110     """
# --> 111     self.on_request(request)
#     112     try:
#     113         response = self.next.send(request)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/keyvault/secrets/_shared/challenge_auth_policy.py:177, in ChallengeAuthPolicy.on_request(self, request)
#     174 if self._need_new_token:
#     175     # azure-identity credentials require an AADv2 scope but the challenge may specify an AADv1 resource
#     176     scope = challenge.get_scope() or challenge.get_resource() + "/.default"
# --> 177     self._request_kv_token(scope, challenge)
#     179 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     180 request.http_request.headers["Authorization"] = f"Bearer {bearer_token}"
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/keyvault/secrets/_shared/challenge_auth_policy.py:263, in ChallengeAuthPolicy._request_kv_token(self, scope, challenge)
#     261     if challenge.tenant_id and not exclude_tenant:
#     262         options["tenant_id"] = challenge.tenant_id
# --> 263     self._token = cast(SupportsTokenInfo, self._credential).get_token_info(scope, options=options)
#     264 else:
#     265     if exclude_tenant:
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/identity/_credentials/default.py:376, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     374 within_dac.set(True)
#     375 try:
# --> 376     token_info = cast(SupportsTokenInfo, super()).get_token_info(*scopes, options=options)
#     377 finally:
#     378     within_dac.set(False)
#
# File ~/Desktop/work/personal/grade_company_kyb/.venv/lib/python3.12/site-packages/azure/identity/_credentials/chained.py:225, in ChainedTokenCredential.get_token_info(self, options, *scopes)
#     217 message = (
#     218     self.__class__.__name__
#     219     + " failed to retrieve a token from the included credentials."
#    (...)    222     "https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot."
#     223 )
#     224 _LOGGER.warning(message)
# --> 225 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: ERROR: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/de176ae2-4ec7-4ee3-bd31-41b09beaa447/' does not exist in tenant 'Default Directory' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: e6a5641e-b5d2-4880-be4c-3176c9810700 Correlation ID: 8e819979-1efe-498b-b424-c28c53d49fdd Timestamp: 2026-02-24 08:55:47Z
# Run the command below to authenticate interactively; additional arguments may be added as needed:
# az logout
# az login --tenant "14ea9a3f-f542-4917-9078-537d7ea3eb33" --scope "https://vault.azure.net/.default"
#
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
